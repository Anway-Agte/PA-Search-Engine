# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('/content/Copy of literature-records_with_pdf.xlsx',header=0)

# %%
data = data.drop(data.columns[0],axis=1)

# %%
data.dropna(subset=['document_link'],inplace=True)

# %%
data.head()
# Out:
#    index cleaned images tables  \
# 2      2       T      T      T
# 4      4       T      T      T
# 5      5       T      T      T
# 8      8       T      T      T
# 9      9       T      T      T
#
#                                        document_link  \
# 2  https://iopscience.iop.org/article/10.1088/030...
# 4  https://journals.aps.org/prl/abstract/10.1103/...
# 5  https://journals.aps.org/prb/abstract/10.1103/...
# 8  https://www.sciencedirect.com/science/article/...
# 9  https://link.springer.com/article/10.1007/BF01...
#
#                                             abstract  \
# 2  The authors have made thermal expansion measur...
# 4  Nuclear magnetic resonance relaxation times fo...
# 5  Experimental studies of helium release from ag...
# 8                                                NaN
# 9  Considerable heat was liberated from a palladi...
#
#                                          all_authors  \
# 2                            Abbenseth, R.; Wipf, H.
# ...

# %%
# !pip install pdfplumber

# %%
paper = data.iloc[0,:]

# %%
paper
# Out:
# index                                                             0
# cleaned                                                         NaN
# images                                                          NaN
# tables                                                          NaN
# document_link                                                   NaN
# abstract                                                        NaN
# all_authors                                                     NaN
# pdf_path                                                        NaN
# title             A Google programme failed to detect cold fusio...
# publisher                                                    Nature
# year_published                                                 2019
# volume                                                          569
# date_uploaded                                                   NaN
# keywords                                                        NaN
# ...

# %%
import pdfplumber
from io import BytesIO
import requests

# %%
req = requests.get(paper.document_link)

# %%
with  pdfplumber.open(BytesIO(req.content)) as pdf:
  if not np.isnan(paper.start):
    print(True)
    pages = []
    for i in range(int(paper.end - paper.start + 1)):
      pages.append(pdf.pages[i])
# Out:
# ---------------------------------------------------------------------------
# PDFSyntaxError                            Traceback (most recent call last)
# <ipython-input-10-9dd255754370> in <cell line: 1>()
# ----> 1 with  pdfplumber.open(BytesIO(req.content)) as pdf:
#       2   if not np.isnan(paper.start):
#       3     print(True)
#       4     pages = []
#       5     for i in range(int(paper.end - paper.start + 1)):
#
# /usr/local/lib/python3.10/dist-packages/pdfplumber/pdf.py in open(cls, path_or_fp, pages, laparams, password, strict_metadata, repair, gs_path)
#      92
#      93         try:
# ---> 94             return cls(
#      95                 stream,
#      96                 path=path,
#
# /usr/local/lib/python3.10/dist-packages/pdfplumber/pdf.py in __init__(self, stream, stream_is_external, path, pages, laparams, password, strict_metadata)
#      42         self.password = password
#      43
# ...

# %%
len(pages)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-004ce89339cd> in <cell line: 1>()
# ----> 1 len(pages)
#
# NameError: name 'pages' is not defined

# %%
text = ''

for page in pages:
  text += page.extract_text()

# %%
text

# %%
paper.document_link

# %%
texts = []
for row in data.itertuples():

  try:
    req = requests.get(row.document_link)
    with  pdfplumber.open(BytesIO(req.content)) as pdf:
      if not np.isnan(row.start):
        print(True)
        pages = []
        for i in range(int(row.end - row.start + 1)):
          pages.append(pdf.pages[i])
        text = ''
        for page in pages:
          text += page.extract_text()
      else:
        text = ''
        for page in pdf.pages:
          text += page.extract_text()

      texts.append(text)
  except :
      texts.append(" ")
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
print(len(texts))
# Out:
# 3203

# %%
data.shape
# Out:
# (3203, 16)

# %%
data.text = texts
# Out:
# <ipython-input-11-63b293378020>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.text = texts

# %%
data['text'] = texts

# %%
data.shape
# Out:
# (3203, 17)

# %%
# !pip install nltk

# %%
# !pip install transformers
# !pip install contractions
# !pip install pyspellchecker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 13.2 MB/s eta 0:00:00
# ...

# %%
import os
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
import pickle
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import string
import re
import nltk
import contractions
from nltk.tokenize import word_tokenize
from spellchecker import SpellChecker
from nltk.stem import PorterStemmer, SnowballStemmer, LancasterStemmer, WordNetLemmatizer

# %%
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def preprocess_text(text):
  text = text.lower()
  text = re.sub('\d+', '', text)
  # remove punctuations
  punctuations = string.punctuation
  text = text.translate(str.maketrans('', '', punctuations))
  # remove special characters
  special_characters = 'å¼«¥ª°©ð±§µæ¹¢³¿®ä£'
  text = text.translate(str.maketrans('', '', special_characters))
  # Expand contractions
  text = contractions.fix(text)
  # remove stopwords
  tokens = word_tokenize(text)
  tokens = [token for token in tokens if token not in stop_words]
  # Spellcheck
  spelling_checker = SpellChecker(language="en", distance=1)
  spelling_checker.word_frequency.load_text_file("ignore_spellcheck_words.txt")
  misspelled = spelling_checker.unknown(tokens)
  for word in misspelled:
    temp = spelling_checker.correction(word)
    if temp:
      tokens[tokens.index(word)] = temp
  # Lemmatization
  lemmatizer = WordNetLemmatizer()
  processed_tokens = [lemmatizer.lemmatize(token) for token in tokens]
  text = " ".join(processed_tokens)
  # remove white space
  text = " ".join(text.split()).strip()

  return text

# %%
data['text'] = data['text'].apply(preprocess_text)

# %%
data.to_pickle("data.pkl")

# %%
data.to_csv("datacsv.csv", escapechar=" ")

# %%
p = pd.read_csv("datacsv.csv")

# %%
p.head()
# Out:
#    Unnamed: 0  index cleaned images tables  \
# 0           2      2       T      T      T
# 1           4      4       T      T      T
# 2           5      5       T      T      T
# 3           8      8       T      T      T
# 4           9      9       T      T      T
#
#                                        document_link  \
# 0  https://iopscience.iop.org/article/10.1088/030...
# 1  https://journals.aps.org/prl/abstract/10.1103/...
# 2  https://journals.aps.org/prb/abstract/10.1103/...
# 3  https://www.sciencedirect.com/science/article/...
# 4  https://link.springer.com/article/10.1007/BF01...
#
#                                             abstract  \
# 0  The  authors  have  made  thermal  expansion  ...
# 1  Nuclear  magnetic  resonance  relaxation  time...
# 2  Experimental  studies  of  helium  release  fr...
# 3                                                NaN
# 4  Considerable  heat  was  liberated  from  a  p...
#
# ...

# %%
p.isnull().sum()
# Out:
# Unnamed: 0           0
# index                0
# cleaned           2834
# images            2917
# tables            2931
# document_link        0
# abstract           210
# all_authors          0
# pdf_path           169
# title                0
# publisher           60
# year_published       0
# volume             908
# date_uploaded     1056
# keywords           279
# start             2205
# end               2206
# text               939
# dtype: int64

# %%
p['text'][p.text.notnull()]
# Out:
# 7       journal  condensed  matter  nuclear  science  ...
# 10      experimental  observation  possible  way  crea...
# 11      adamenkosandvvysotskiithepossiblemechanismofcr...
# 13      adzicrret  al  tritiummeasurements  anddeuteri...
# 14      i  cidcidcid  glwhgcideciddocidr  glwrucidlqci...
#                               ...
# 3189    i  cidcidcid  glwhgcideciddocidr  glwrucidlqci...
# 3190    journal  condensed  matter  nuclear  science  ...
# 3191    zhou  i  i  li  i  liu  bathe  calculation  so...
# 3199    journal  condensed  matter  nuclear  science  ...
# 3200    journal  condensed  matter  nuclear  science  ...
# Name: text, Length: 2264, dtype: object

# %%
p['text'][7]
# Out:
# 'journal  condensed  matter  nuclear  science  experiment  method  cold  fusion  volume  november  journal  condensed  matter  nuclear  science  experimentsandmethodsincoldfusion  editorinchief  jeanpaulbiberian  marseillefrance  editorialboard  peterhagelstein  xingzhongli  edmundstorms  mitusa  tsinghuauniversitychina  kivalabsllcusa  georgemiley  michaelmckubre  fusionstudieslaboratory  sriinternationalusa  universityofillinoisusajournal  condensed  matter  nuclear  science  volume  november  iscmnsallrightsreserved  isn  thisjournalandtheindividualcontributionscontainedinitareprotectedundercopyrightbyiscmnsandthefollowing  termsandconditionsapply  electronicusageorstorageofdata  jcmnsisanopenaccessscientificjournalandnospecialpermissionsorfeesarerequiredtodownloadforpersonal  noncommercialuseorforteachingpurposesinaneducationalinstitution  allotherusesincludingprintingcopyingdistributionrequirethewrittenconsentofiscmns  permission  iscmns  payment  fee  required  photocopying  in
# ...
